# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# This notebook presents PyMC implementations of the Bayesian simple linear regression models described in [Kruschke](http://amzn.com/0123814855), Ch. 16. We'll start with a no-frills linear regression of a single metric response on a single metric predictor, then modify that for robustness, and finally add hierarchy to deal with repeated measures among multiple subjects.

# %%
# Set up the environment for successive computational cells. 
# This stuff will not be repeated below, be sure to run this cell first.

import pymc as mc
import numpy as np
import pandas as pd
from IPython.display import Image

class Struct:
    # convenience 'bag of attributes' class
    def __init__(self, **entries): self.__dict__.update(entries)

def show_graph(model):
    """display a graphical representation of the model"""
    graph = mc.graph.graph(model)
    Image(graph.create_png())

def posterior_hist(trace, label="", HDI=.95, alpha=1.0):   
    """Render a histogram of the posterior sampling distribution of a model variable."""
    t = sorted(trace)
    h = hist(t, normed=True, alpha=alpha, label="%s:%.2f" % (label, mean(t)))
    ymax = max(h[0])
    axvline(mean(t), c='red', linestyle='-.')
    hdidx = int(len(t)*(1 - HDI)/2.) 
    annotate("", xy=(t[hdidx],0), xytext=(t[-hdidx],0),
             arrowprops=dict(arrowstyle="|-|", connectionstyle="arc3", color='k',lw=2))
    
def ci_patch(x, ci, **kwds):
    """create a bounding polygon for the confidence intervals vs x"""
    x, ci = zip(*sorted(zip(x,ci))) # sort x and ci by x
    cit = zip(*ci) 
    diff = np.array(cit[1]) - np.array(cit[0])
    print "CI: min=%f, max=%f" % (min(diff), max(diff))
    return Polygon(zip(x,cit[0]) + zip(x, cit[1])[::-1], **kwds)

def predict_ci(mu, tau, HDI=.95):
    """sample the posterior distribution of predicted y's using 
       values from the parameter traces to construct normal distributions
       from which to sample. return the specified
       HDI confidence interval."""
    y_pred = []
    if hasattr(tau, 'trace'):
        tau_trace = tau.trace()
    else:
        tau_trace = np.ones(len(mu.trace())) * tau
    for mui, taui in zip(mu.trace(), tau_trace):
        y_pred.extend(np.random.normal(loc=mui, scale=sqrt(1/taui), size=1000))
    y_pred = sort(y_pred)
    hdidx = int(len(y_pred)*(1 - HDI)/2.) 
    return (y_pred[hdidx], y_pred[-hdidx])

def plot_regression(x, y, mu, tau, titlestr="", HDI=.95):
    """plot the regression results. X and Y are vectors of floats, 
       mu is a list of regression mean stochastics for y[i] on x[i],
       tau is the precision stochastic"""
    ax = gca()
    ax.scatter(x,y,color='k')
    if hasattr(x,'name'):
        xlabel(x.name)
    if hasattr(y,'name'):
        ylabel(y.name)
    if titlestr:
        title(titlestr)
    if hasattr(mu[0], 'trace'):
        means = [mui.stats()['mean'] for mui in mu]
        slope = mu[0].parents['y'][1].stats()['mean']
    else:
        means = [mui.value for mui in mu]
        slope = mu[0].parents['y'][1].value
    sx, smeans = zip(*sorted(zip(x, means))) # sort x,mean pairs by x and return as lists
    ax.plot(sx, smeans, color='b', label="slope=%f" % slope)
    legend()
    # 95% ci for the mean
    if hasattr(mu[0], 'trace'):
        ci_mu = [tuple(mui.stats()['95% HPD interval']) for mui in mu]
        ax.add_patch(ci_patch(x, ci_mu, color='b', alpha=.2))
        draw_if_interactive()    
        # 95% ci for the predicted y's
        ci_y = [predict_ci(mui, tau, HDI) for mui in mu]
        ax.add_patch(ci_patch(x, ci_y, color='k', alpha=.2))
        draw_if_interactive()    
    else:
        # 95% ci for predicted y's assuming normal centered at current mu
        ci_y = [(mui.value - 1.96/sqrt(tau.value), mui.value + 1.96/sqrt(tau.value)) for mui in mu] 
        ax.add_patch(ci_patch(x, ci_y, color='r', alpha=.2))
        draw_if_interactive()

# %% [markdown]
# The first data set is height and weight pairs randomly generated using Kruschke's HtWtDataGenerator.R and saved as htwt.csv for loading here:

# %%
# Note: when reading, do not let column 0 be used as the index. 
# It starts at 1, and you will later be in a world of pain
# wondering whether you are referring to the item at position
# 1 or the item named 1 (which is in position 0). 
htwt = pd.read_csv("data/htwt.csv", index_col=None)
htwt.describe()
# Out:
#        Unnamed: 0       male     height      weight
# count   30.000000  30.000000  30.000000   30.000000
# mean    15.500000   0.500000  65.726667  164.996667
# std      8.803408   0.508548   4.714317   38.882923
# min      1.000000   0.000000  56.600000   99.300000
# 25%      8.250000   0.000000  61.875000  144.175000
# 50%     15.500000   0.500000  66.200000  157.300000
# 75%     22.750000   1.000000  68.900000  184.750000
# max     30.000000   1.000000  75.800000  260.900000

# %%
scatter(htwt.height, htwt.weight);

# %% [markdown]
# We will fit a simple generalized linear model for weight (y) predicted by height (x):
#
# $y_i \sim N(\mu_i, \tau)$
#
# $\mu_i = \beta_0 + \beta_1x_i$
#
# $\tau = 1/\sigma^2$

# %%
import pymc as pm

def make_normal_model(x, y):
    """
    return a dict of model variables for the model constructor
    """
    # priors for the regression coefficients and variance/precision.
    # initialize beta to suit the data, or the MAP initializer may not converge.
    beta = mc.Container((mc.Normal("beta_0", mu=mean(y), tau=1e-12, value=mean(y)), # population intercept
                         mc.Normal("beta_1", mu=0, tau=1e-12, value=0))) # population slope
    tau = mc.Gamma("tau", alpha=.001, beta=.001, value=.001)   # population precision

    # The distribution of each y_i has mean that is a deterministic function of the x_i
    mu = mc.Container([mc.LinearCombination("mu_%d" % i, (1, x[i]), beta)
                       for i in x.index])

    # likelihood for the data
    y_obs = mc.Container([mc.Normal("y_%d" % i, mu=mu[i], tau=tau, value=y[i], observed=True) 
                          for i in y.index])
    
    return mc.Model(input=locals())

M = make_normal_model(htwt.height, htwt.weight)
print M.beta[0].value, M.beta[1].value
figure()
plot_regression(htwt.height, htwt.weight, M.mu, M.tau, "pre MAP estimate")
show()
mc.MAP(M).fit()
plot_regression(htwt.height, htwt.weight, M.mu, M.tau, "initial MAP estimate")
show()
S = mc.MCMC(input=M, db='ram')
# Out:
# 164.996666667 0.0
# CI: min=123.961284, max=123.961284
# CI: min=141.768611, max=141.768611

# %%
S.sample(10000, burn=1000, thin=10)
S.summary()
mc.Matplot.plot(S)
# Out:
#  [-                 2%                  ] 293 of 10000 complete in 0.5 sec
#  [--                6%                  ] 600 of 10000 complete in 1.0 sec
#  [---               9%                  ] 912 of 10000 complete in 1.5 sec
#  [----             12%                  ] 1218 of 10000 complete in 2.0 sec
#  [-----            14%                  ] 1465 of 10000 complete in 2.5 sec
#  [------           17%                  ] 1768 of 10000 complete in 3.0 sec
#  [-------          20%                  ] 2008 of 10000 complete in 3.5 sec
#  [--------         23%                  ] 2361 of 10000 complete in 4.0 sec
#  [----------       26%                  ] 2646 of 10000 complete in 4.5 sec
#  [-----------      29%                  ] 2963 of 10000 complete in 5.0 sec
#  [------------     32%                  ] 3266 of 10000 complete in 5.5 sec
#  [-------------    35%                  ] 3575 of 10000 complete in 6.0 sec
#  [--------------   38%                  ] 3873 of 10000 complete in 6.5 sec
#  [---------------  41%                  ] 4189 of 10000 complete in 7.0 sec
#  [-----------------45%                  ] 4515 of 10000 complete in 7.5 sec
#  [-----------------48%                  ] 4810 of 10000 complete in 8.0 sec
#  [-----------------51%                  ] 5123 of 10000 complete in 8.5 sec
#  [-----------------54%                  ] 5438 of 10000 complete in 9.0 sec
#  [-----------------57%-                 ] 5744 of 10000 complete in 9.5 sec
#  [-----------------60%--                ] 6052 of 10000 complete in 10.0 sec
#  [-----------------63%----              ] 6346 of 10000 complete in 10.5 sec
#  [-----------------66%-----             ] 6687 of 10000 complete in 11.0 sec
#  [-----------------70%------            ] 7012 of 10000 complete in 11.5 sec
#  [-----------------73%-------           ] 7324 of 10000 complete in 12.0 sec
#  [-----------------76%---------         ] 7639 of 10000 complete in 12.5 sec
#  [-----------------79%----------        ] 7963 of 10000 complete in 13.0 sec
#  [-----------------82%-----------       ] 8285 of 10000 complete in 13.5 sec
#  [-----------------85%------------      ] 8580 of 10000 complete in 14.0 sec
#  [-----------------89%-------------     ] 8906 of 10000 complete in 14.5 sec
#  [-----------------92%---------------   ] 9248 of 10000 complete in 15.0 sec
#  [-----------------95%----------------  ] 9563 of 10000 complete in 15.5 sec
#  [-----------------98%----------------- ] 9890 of 10000 complete in 16.0 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 16.2 sec
# mu_4:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	165.529          6.907            0.244        [ 151.697  179.082]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	151.783          160.881         165.303        170.106       179.68
#
#
# mu_7:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	158.139          7.463            0.387        [ 143.649  172.539]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	143.274          152.981         157.95         163.053       172.423
#
#
# mu_11:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	151.94           8.762            0.604        [ 134.073  167.6  ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	134.914          145.92          152.136        157.622       168.884
#
#
# mu_6:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	181.502          9.706            0.693        [ 164.256  201.111]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	163.386          174.611         181.47         188.202       200.326
#
#
# mu_24:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	166.721          6.941            0.249        [ 152.94   180.292]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	153.256          162.073         166.509        171.312       181.038
#
#
# mu_5:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	143.596          11.219           0.924        [ 122.332  163.588]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	123.677          135.504         143.263        151.33        166.074
#
#
# mu_18:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	168.628          7.065            0.274        [ 154.872  182.886]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	154.931          163.837         168.447        172.941       183.256
#
#
# mu_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	157.423          7.58             0.41         [ 142.888  172.563]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	142.21           152.228         157.349        162.311       172.046
#
#
# mu_17:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	170.536          7.274            0.317        [ 157.949  186.481]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	156.211          165.482         170.37         175.014       185.766
#
#
# beta_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	8.66             64.974           6.375        [ -91.8    141.397]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-90.353          -42.196         -3.443         64.804        145.369
#
#
# mu_16:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	168.628          7.065            0.274        [ 154.872  182.886]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	154.931          163.837         168.447        172.941       183.256
#
#
# mu_25:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	155.755          7.889            0.466        [ 138.481  169.478]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	139.861          150.271         155.788        161.086       171.121
#
#
# mu_19:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	157.423          7.58             0.41         [ 142.888  172.563]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	142.21           152.228         157.349        162.311       172.046
#
#
# mu_10:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	170.536          7.274            0.317        [ 157.949  186.481]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	156.211          165.482         170.37         175.014       185.766
#
#
# mu_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	175.065          8.061            0.457        [ 160.929  192.161]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	159.913          169.768         174.868        180.206       191.616
#
#
# beta_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	2.384            0.985            0.097            [ 0.314  3.848]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	0.395            1.532           2.578          3.133         3.96
#
#
# tau:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	0.001            0.0              0.0              [ 0.     0.001]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	0.0              0.001           0.001          0.001         0.001
#
#
# mu_13:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	189.37           12.212           0.998        [ 166.914  211.721]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	166.245          180.371         189.599        198.416       211.126
#
#
# mu_20:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	161.238          7.076            0.3          [ 146.687  174.743]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	146.741          156.576         161.048        165.972       175.3
#
#
# mu_12:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	172.204          7.519            0.364        [ 159.478  188.87 ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	157.508          167.002         172.087        176.801       187.854
#
#
# mu_14:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	176.734          8.438            0.516        [ 160.869  193.273]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	161.141          171.051         176.585        182.346       193.783
#
#
# mu_27:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	154.563          8.139            0.508        [ 137.159  168.942]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	138.394          148.949         154.555        159.875       170.498
#
#
# mu_21:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	173.158          7.684            0.394        [ 160.385  190.292]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	158.392          167.989         172.964        177.884       188.847
#
#
# mu_15:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	147.649          9.952            0.767        [ 128.586  165.542]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	129.172          140.613         147.45         154.236       166.973
#
#
# mu_2:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	150.271          9.202            0.666        [ 132.813  167.517]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	132.95           143.852         150.18         156.327       168.005
#
#
# mu_28:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	174.589          7.961            0.441        [ 161.086  192.139]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	159.467          169.426         174.502        179.58        190.896
#
#
# mu_22:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	178.641          8.914            0.585        [ 163.023  196.432]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	162.066          172.379         178.574        184.618       196.331
#
#
# mu_26:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	170.536          7.274            0.317        [ 157.949  186.481]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	156.211          165.482         170.37         175.014       185.766
#
#
# mu_3:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	166.244          6.923            0.246        [ 152.457  179.703]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	152.733          161.58          166.031        170.817       180.593
#
#
# mu_9:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	182.217          9.915            0.72         [ 163.772  201.334]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	163.693          175.186         182.183        189.23        201.262
#
#
# mu_29:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	162.907          6.958            0.267        [ 148.513  176.48 ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	148.91           158.382         162.715        167.491       176.987
#
#
# mu_23:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	155.278          7.987            0.483        [ 138.329  169.478]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	139.163          149.686         155.292        160.453       171.087
#
#
# mu_8:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	153.609          8.355            0.543        [ 135.765  168.135]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	137.263          147.927         153.769        159.13        169.764
#
# Plotting mu_4
# Plotting
#  mu_7
# Plotting
#  mu_11
# Plotting
#  mu_6
# Plotting
#  mu_24
# Plotting
#  mu_5
# Plotting
#  mu_18
# Plotting
#  mu_1
# Plotting
#  mu_17
# Plotting
#  beta_0
# Plotting
#  mu_16
# Plotting
#  mu_25
# Plotting
#  mu_19
# Plotting
#  mu_10
# Plotting
#  mu_0
# Plotting
#  beta_1
# Plotting
#  tau
# Plotting
#  mu_13
# Plotting
#  mu_20
# Plotting
#  mu_12
# Plotting
#  mu_14
# Plotting
#  mu_27
# Plotting
#  mu_21
# Plotting
#  mu_15
# Plotting
#  mu_2
# Plotting
#  mu_28
# Plotting
#  mu_22
# Plotting
#  mu_26
# Plotting
#  mu_3
# Plotting
#  mu_9
# Plotting
#  mu_29
# Plotting
#  mu_23
# Plotting
#  mu_8
# /Users/welch/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# On to the results:

# %%
plot_regression(htwt.height, htwt.weight, M.mu, M.tau, "MC posterior estimate")
figure()
posterior_hist(M.beta[0].trace(), "beta0")
legend()
show()
posterior_hist(M.beta[1].trace(), "beta1")
legend()
show()
# Out:
# CI: min=27.245616, max=44.807836
# CI: min=150.057780, max=155.003649

# %% [markdown]
# The blue area is the 95% confidence interval around the estimated mean for each y. The gray area is the 95% HDI of predicted y's drawn as samples from distributions of $\mu$ and $\tau$.

# %% [markdown]
# ### Centered Data

# %% [markdown]
# Although the point results above look reasonable, there is a lot of variation in the shapes of the posteriors over repreated runs. And occasionally the MAP estimate blows up and the sampling run never recovers. This is because credible values of $\beta_0$ and $\beta_1$ are highly negatively correlated (a higher y-intercept implies a lower slope so the line will go through the center of the data mass). The MCMC can have trouble traversing the sample space because it cannot change $\beta_0$ and $\beta_1$ independently without falling out of the credible region.
#
# The standard cure for this is to first center the data:

# %%
h = pd.Series(htwt.height - htwt.height.mean(), name="height - %d" % int(htwt.height.mean()))
w = pd.Series(htwt.weight - htwt.weight.mean(), name="weight - %d" % int(htwt.weight.mean()))
M = make_normal_model(h,w)
mc.MAP(M).fit()
plot_regression(h, w, M.mu, M.tau, "initial MAP estimate")
show()
# Out:
# CI: min=155.304343, max=155.304343

# %%
S_c = mc.MCMC(input=M, db='ram')
S_c.sample(10000, burn=1000, thin=10)
S_c.summary()
# Out:
#  [-                 3%                  ] 330 of 10000 complete in 0.5 sec
#  [--                6%                  ] 664 of 10000 complete in 1.0 sec
#  [---              10%                  ] 1038 of 10000 complete in 1.5 sec
#  [-----            13%                  ] 1380 of 10000 complete in 2.0 sec
#  [------           17%                  ] 1720 of 10000 complete in 2.5 sec
#  [-------          20%                  ] 2082 of 10000 complete in 3.0 sec
#  [---------        24%                  ] 2429 of 10000 complete in 3.5 sec
#  [----------       27%                  ] 2793 of 10000 complete in 4.0 sec
#  [-----------      31%                  ] 3131 of 10000 complete in 4.5 sec
#  [-------------    34%                  ] 3471 of 10000 complete in 5.0 sec
#  [--------------   37%                  ] 3798 of 10000 complete in 5.5 sec
#  [---------------  41%                  ] 4125 of 10000 complete in 6.0 sec
#  [-----------------44%                  ] 4487 of 10000 complete in 6.5 sec
#  [-----------------48%                  ] 4841 of 10000 complete in 7.0 sec
#  [-----------------52%                  ] 5207 of 10000 complete in 7.5 sec
#  [-----------------55%-                 ] 5552 of 10000 complete in 8.0 sec
#  [-----------------59%--                ] 5922 of 10000 complete in 8.5 sec
#  [-----------------62%---               ] 6278 of 10000 complete in 9.0 sec
#  [-----------------66%-----             ] 6632 of 10000 complete in 9.5 sec
#  [-----------------70%------            ] 7007 of 10000 complete in 10.0 sec
#  [-----------------73%--------          ] 7392 of 10000 complete in 10.5 sec
#  [-----------------77%---------         ] 7772 of 10000 complete in 11.0 sec
#  [-----------------81%----------        ] 8147 of 10000 complete in 11.5 sec
#  [-----------------85%------------      ] 8528 of 10000 complete in 12.0 sec
#  [-----------------88%-------------     ] 8880 of 10000 complete in 12.5 sec
#  [-----------------92%---------------   ] 9216 of 10000 complete in 13.0 sec
#  [-----------------95%----------------  ] 9564 of 10000 complete in 13.5 sec
#  [-----------------98%----------------- ] 9883 of 10000 complete in 14.0 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 14.2 sec
# beta_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	2.899            1.753            0.122            [-0.245  5.748]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.218           1.777           3.076          4.079         5.989
#
#
# beta_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-0.0             0.0              0.0                    [-0.  0.]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.001           -0.0            0.0            0.0           0.0
#
#
# mu_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-9.643           5.831            0.407          [-19.123   0.816]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-19.923          -13.556         -10.224        -5.878        0.726
#
#
# mu_8:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-14.281          8.635            0.603          [-28.32    1.209]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-29.505          -20.075         -15.141        -8.704        1.075
#
#
# mu_15:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-21.528          13.017           0.909          [-42.691   1.822]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-44.477          -30.262         -22.825        -13.121       1.621
#
#
# mu_16:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	3.981            2.407            0.168            [-0.337  7.895]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.3             2.441           4.224          5.603         8.225
#
#
# mu_29:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-2.976           1.8              0.126            [-5.902  0.252]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-6.148           -4.184          -3.155         -1.814        0.224
#
#
# mu_6:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	19.634           11.872           0.829          [ -1.662  38.936]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-1.478           12.038          20.833         27.632        40.564
#
#
# mu_21:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	9.488            5.737            0.401          [ -0.803  18.817]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.714           5.818           10.068         13.354        19.603
#
#
# mu_25:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-11.672          7.058            0.493          [-23.147   0.988]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-24.115          -16.408         -12.375        -7.114        0.879
#
#
# mu_10:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	6.3              3.809            0.266          [ -0.533  12.493]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.474           3.863           6.684          8.866         13.016
#
#
# mu_12:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	8.329            5.036            0.352          [ -0.705  16.517]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.627           5.107           8.837          11.722        17.208
#
#
# mu_14:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.836           8.367            0.584          [ -1.171  27.439]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-1.041           8.484           14.681         19.473        28.586
#
#
# mu_26:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	6.3              3.809            0.266          [ -0.533  12.493]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.474           3.863           6.684          8.866         13.016
#
#
# mu_18:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	3.981            2.407            0.168            [-0.337  7.895]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.3             2.441           4.224          5.603         8.225
#
#
# tau:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	0.001            0.0              0.0              [ 0.     0.001]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	0.0              0.001           0.001          0.001         0.001
#
#
# mu_2:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-18.339          11.089           0.774          [-36.368   1.552]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-37.889          -25.78          -19.444        -11.178       1.381
#
#
# mu_3:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	1.082            0.654            0.046            [-0.092  2.146]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.081           0.664           1.148          1.524         2.236
#
#
# mu_28:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	11.228           6.789            0.474          [ -0.95   22.266]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.845           6.884           11.913         15.802        23.197
#
#
# mu_4:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	0.213            0.129            0.009            [-0.018  0.422]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.016           0.13            0.226          0.299         0.439
#
#
# mu_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	11.807           7.14             0.498          [ -1.     23.415]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.889           7.24            12.528         16.617        24.394
#
#
# mu_17:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	6.3              3.809            0.266          [ -0.533  12.493]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.474           3.863           6.684          8.866         13.016
#
#
# mu_20:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-5.005           3.026            0.211            [-9.925  0.424]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-10.341          -7.036          -5.307         -3.051        0.377
#
#
# mu_9:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	20.503           12.398           0.866          [ -1.736  40.661]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-1.543           12.572          21.755         28.856        42.361
#
#
# mu_7:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-8.773           5.305            0.37           [-17.398   0.743]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-18.126          -12.333         -9.302         -5.348        0.661
#
#
# mu_27:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-13.121          7.934            0.554          [-26.021   1.111]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-27.109          -18.445         -13.912        -7.998        0.988
#
#
# mu_24:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	1.662            1.005            0.07             [-0.141  3.296]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-0.125           1.019           1.763          2.339         3.434
#
#
# mu_23:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-12.252          7.408            0.517          [-24.296   1.037]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-25.313          -17.223         -12.99         -7.468        0.923
#
#
# mu_22:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	16.155           9.769            0.682          [ -1.368  32.038]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-1.216           9.906           17.142         22.737        33.378
#
#
# mu_11:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-16.31           9.862            0.689          [-32.344   1.381]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-33.697          -22.928         -17.293        -9.941        1.228
#
#
# mu_5:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-26.455          15.997           1.117          [-52.464   2.24 ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-54.658          -37.19          -28.05         -16.125       1.992
#
#
# mu_19:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	-9.643           5.831            0.407          [-19.123   0.816]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-19.923          -13.556         -10.224        -5.878        0.726
#
#
# mu_13:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	29.199           17.656           1.233          [ -2.472  57.906]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-2.198           17.904          30.982         41.094        60.327

# %%
plot_regression(h, w, M.mu, M.tau, "MC posterior estimate")
show()
posterior_hist(M.beta[0].trace(), "beta0")
legend()
show()
posterior_hist(M.beta[1].trace(), "beta1")
legend()
show()
# Out:
# CI: min=0.439672, max=60.377608
# CI: min=147.152399, max=162.955667

# %% [markdown]
# The $\beta_1$ estimate is nearly the same as before. But this yields much tidier-looking $\beta$ posteriors, with a much tighter interval for $\beta_0$ around 0.

# %% [markdown]
# ## Robust Regression

# %% [markdown]
# The normal likelihood used for $\mu_i$ is sensitive to outliers. The example in section 16.2 demonstrates this with data for 25 brands of cigarettes ([McIntyre1994](data/McIntyre1994data.csv)), attempting to predict tar content from weight:

# %%
cig = pd.read_csv("data/McIntyre1994data.csv")
print cig
# Out:
#                Brand   Tar   Nic      Wt    CO
# 0             Alpine  14.1  0.86  0.9853  13.6
# 1    BensonAndHedges  16.0  1.06  1.0938  16.6
# 2         BullDurham  29.8  2.03  1.1650  23.5
# 3        CamelLights   8.0  0.67  0.9280  10.2
# 4            Carlton   4.1  0.40  0.9462   5.4
# 5       Chesterfield  15.0  1.04  0.8885  15.0
# 6       GoldenLights   8.8  0.76  1.0267   9.0
# 7               Kent  12.4  0.95  0.9225  12.3
# 8               Kool  16.6  1.12  0.9372  16.3
# 9              LandM  14.9  1.02  0.8858  15.4
# 10        LarkLights  13.7  1.01  0.9643  13.0
# 11          Marlboro  15.1  0.90  0.9316  14.4
# 12             Merit   7.8  0.57  0.9705  10.0
# 13       MultiFilter  11.4  0.78  1.1240  10.2
# 14     NewportLights   9.0  0.74  0.8517   9.5
# 15               Now   1.0  0.13  0.7851   1.5
# 16           OldGold  17.0  1.26  0.9186  18.5
# 17     PallMallLight  12.8  1.08  1.0395  12.6
# 18           Raleigh  15.8  0.96  0.9573  17.5
# 19        SalemUltra   4.5  0.42  0.9106   4.9
# 20          Tareyton  14.5  1.01  1.0070  15.9
# 21              True   7.3  0.61  0.9806   8.5
# 22  ViceroyRichLight   8.6  0.69  0.9693  10.6
# 23     VirginiaSlims  15.2  1.02  0.9496  13.9
# 24     WinstonLights  12.0  0.82  1.1184  14.9

# %%
#w = pd.Series(cig.Wt - cig.Wt.mean(), name="Weight - %d" % cig.Wt.mean())
#t = pd.Series(cig.Tar - cig.Tar.mean(), name="Tar - %d" % cig.Tar.mean())
w = cig.Wt
t = cig.Tar
figure()
M = make_normal_model(w, t)
mc.MAP(M).fit()
plot_regression(w, t, M.mu, M.tau, "initial MAP estimate")
show()
# Out:
# CI: min=19.766757, max=19.766757

# %%
S = mc.MCMC(input=M, db='ram')
S.sample(10000, burn=1000, thin=10)
mc.Matplot.plot(S)
# Out:
#  [-                 3%                  ] 329 of 10000 complete in 0.5 sec
#  [--                6%                  ] 658 of 10000 complete in 1.0 sec
#  [---              10%                  ] 1010 of 10000 complete in 1.5 sec
#  [-----            13%                  ] 1348 of 10000 complete in 2.0 sec
#  [------           16%                  ] 1662 of 10000 complete in 2.5 sec
#  [-------          19%                  ] 1994 of 10000 complete in 3.0 sec
#  [--------         23%                  ] 2337 of 10000 complete in 3.5 sec
#  [----------       26%                  ] 2672 of 10000 complete in 4.0 sec
#  [-----------      30%                  ] 3022 of 10000 complete in 4.5 sec
#  [------------     34%                  ] 3417 of 10000 complete in 5.0 sec
#  [--------------   37%                  ] 3745 of 10000 complete in 5.5 sec
#  [---------------  40%                  ] 4099 of 10000 complete in 6.0 sec
#  [---------------- 44%                  ] 4429 of 10000 complete in 6.5 sec
#  [-----------------47%                  ] 4794 of 10000 complete in 7.0 sec
#  [-----------------51%                  ] 5154 of 10000 complete in 7.5 sec
#  [-----------------55%-                 ] 5535 of 10000 complete in 8.0 sec
#  [-----------------59%--                ] 5914 of 10000 complete in 8.5 sec
#  [-----------------63%---               ] 6305 of 10000 complete in 9.0 sec
#  [-----------------66%-----             ] 6657 of 10000 complete in 9.5 sec
#  [-----------------70%------            ] 7005 of 10000 complete in 10.0 sec
#  [-----------------73%-------           ] 7352 of 10000 complete in 10.5 sec
#  [-----------------77%---------         ] 7718 of 10000 complete in 11.0 sec
#  [-----------------80%----------        ] 8076 of 10000 complete in 11.5 sec
#  [-----------------84%------------      ] 8425 of 10000 complete in 12.0 sec
#  [-----------------87%-------------     ] 8785 of 10000 complete in 12.5 sec
#  [-----------------91%--------------    ] 9142 of 10000 complete in 13.0 sec
#  [-----------------95%----------------  ] 9500 of 10000 complete in 13.5 sec
#  [-----------------98%----------------- ] 9850 of 10000 complete in 14.0 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 14.2 sec
# Plotting mu_17
# Plotting
#  mu_8
# Plotting
#  mu_4
# Plotting
#  mu_24
# Plotting
#  mu_0
# Plotting
#  mu_11
# Plotting
#  mu_2
# Plotting
#  mu_23
# Plotting
#  mu_21
# Plotting
#  mu_20
# Plotting
#  mu_16
# Plotting
#  tau
# Plotting
#  mu_15
# Plotting
#  mu_1
# Plotting
#  mu_10
# Plotting
#  mu_22
# Plotting
#  mu_6
# Plotting
#  mu_13
# Plotting
#  mu_7
# Plotting
#  beta_1
# Plotting
#  mu_14
# Plotting
#  beta_0
# Plotting
#  mu_5
# Plotting
#  mu_3
# Plotting
#  mu_18
# Plotting
#  mu_9
# Plotting
#  mu_12
# Plotting
#  mu_19

# %%
plot_regression(w, t, M.mu, M.tau)
show()
posterior_hist(M.beta[0].trace(), "beta0")
legend()
show()
posterior_hist(M.beta[1].trace(), "beta1")
legend()
show()
# Out:
# CI: min=4.018243, max=7.914703
# CI: min=21.321870, max=22.370185

# %% [markdown]
# The point at the upper right exerts enough influence on the slope (via the Normal likelihood) that the value 0 is not in the credible HDI. Kruschke suggests replacing the Normal likelihood with a t-distributed likelihood, whose fatter tails accommodate observations outside the normal distribution. The degrees-of-freedom parameter will be treated as a continuous adjustment of the fatness of the tails, and will be estimated along with the other model parameters, biased towards smaller values:

# %%
def make_t_model(x, y):
    """
    return a dict of model variables for the model constructor
    """
    # priors for the regression coefficients and variance/precision
    beta = mc.Container((mc.Normal("beta_0", mu=0, tau=1e-12, value=mean(y)), # population intercept
                         mc.Normal("beta_1", mu=0, tau=1e-12, value=0))) # population slope
    tau = mc.Gamma("tau", alpha=.001, beta=.001, value=.001)   # population precision
    sigma = mc.Lambda("sigma", lambda tau=tau: tau**-0.5)
    nuGain = 1
    udf = mc.Uniform("udf", 0, 1.0, value=0)
    nu = mc.Lambda("nu", lambda udf=udf: 1 - nuGain * np.log(1 - udf)) # nu range [1,infty)

    # The distribution of each y_i has mean that is a deterministic function of the x_i
    mu = mc.Container([mc.LinearCombination("mu_%d" % i, (1, x[i]), beta)
                       for i in x.index])

    # likelihood for the data
    z_like = mc.Container([mc.NoncentralT("z_like_%d" % i, mu=mu[i], lam=sigma, nu=nu, value=y[i], observed=True)
                          for i in y.index])
        
    return mc.Model(input=locals())

# %%
M = make_t_model(cig.Wt, cig.Tar)
plot_regression(cig.Wt, cig.Tar, M.mu, M.tau, "pre MAP estimate")
show()
mc.MAP(M).fit()
plot_regression(cig.Wt, cig.Tar, M.mu, M.tau, "MAP estimate")
show()
# Out:
# CI: min=123.961284, max=123.961284
# CI: min=2.213497, max=2.213497

# %%
S = mc.MCMC(input=M, db='ram')
S.sample(10000, burn=1000, thin=10)
S.summary()
# Out:
#  [                  2%                  ] 218 of 10000 complete in 0.5 sec
#  [-                 4%                  ] 458 of 10000 complete in 1.0 sec
#  [--                6%                  ] 696 of 10000 complete in 1.5 sec
#  [---               8%                  ] 886 of 10000 complete in 2.0 sec
#  [----             11%                  ] 1118 of 10000 complete in 2.5 sec
#  [-----            13%                  ] 1338 of 10000 complete in 3.0 sec
#  [------           15%                  ] 1580 of 10000 complete in 3.5 sec
#  [------           18%                  ] 1819 of 10000 complete in 4.0 sec
#  [-------          20%                  ] 2051 of 10000 complete in 4.5 sec
#  [--------         22%                  ] 2271 of 10000 complete in 5.0 sec
#  [---------        25%                  ] 2511 of 10000 complete in 5.5 sec
#  [----------       27%                  ] 2739 of 10000 complete in 6.0 sec
#  [-----------      29%                  ] 2979 of 10000 complete in 6.5 sec
#  [------------     32%                  ] 3205 of 10000 complete in 7.0 sec
#  [-------------    34%                  ] 3436 of 10000 complete in 7.5 sec
#  [-------------    36%                  ] 3675 of 10000 complete in 8.0 sec
#  [--------------   39%                  ] 3905 of 10000 complete in 8.5 sec
#  [---------------  41%                  ] 4139 of 10000 complete in 9.0 sec
#  [---------------- 43%                  ] 4363 of 10000 complete in 9.5 sec
#  [-----------------45%                  ] 4593 of 10000 complete in 10.0 sec
#  [-----------------48%                  ] 4838 of 10000 complete in 10.5 sec
#  [-----------------50%                  ] 5072 of 10000 complete in 11.0 sec
#  [-----------------53%                  ] 5308 of 10000 complete in 11.5 sec
#  [-----------------55%-                 ] 5541 of 10000 complete in 12.0 sec
#  [-----------------57%-                 ] 5784 of 10000 complete in 12.5 sec
#  [-----------------60%--                ] 6023 of 10000 complete in 13.0 sec
#  [-----------------62%---               ] 6258 of 10000 complete in 13.5 sec
#  [-----------------65%----              ] 6509 of 10000 complete in 14.0 sec
#  [-----------------67%-----             ] 6738 of 10000 complete in 14.5 sec
#  [-----------------69%------            ] 6988 of 10000 complete in 15.0 sec
#  [-----------------72%-------           ] 7230 of 10000 complete in 15.5 sec
#  [-----------------74%--------          ] 7473 of 10000 complete in 16.0 sec
#  [-----------------77%---------         ] 7709 of 10000 complete in 16.5 sec
#  [-----------------79%----------        ] 7952 of 10000 complete in 17.0 sec
#  [-----------------81%-----------       ] 8189 of 10000 complete in 17.5 sec
#  [-----------------84%------------      ] 8439 of 10000 complete in 18.0 sec
#  [-----------------86%------------      ] 8677 of 10000 complete in 18.5 sec
#  [-----------------89%-------------     ] 8919 of 10000 complete in 19.0 sec
#  [-----------------91%--------------    ] 9161 of 10000 complete in 19.6 sec
#  [-----------------94%---------------   ] 9407 of 10000 complete in 20.1 sec
#  [-----------------96%----------------  ] 9646 of 10000 complete in 20.6 sec
#  [-----------------99%----------------- ] 9903 of 10000 complete in 21.1 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 21.3 sec
# mu_19:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.713           1.959            0.167          [  9.131  15.965]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	8.447            11.396          12.964         14.283        15.607
#
#
# mu_22:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.97            1.275            0.074          [ 10.138  14.938]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.845            12.226          13.2           13.896        14.815
#
#
# mu_8:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.829           1.607            0.124            [  9.64  15.35]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.226            11.852          13.107         14.035        15.164
#
#
# tau:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	119.084          121.812          8.925        [   0.718  376.128]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	5.25             32.683          79.744         162.518       484.861
#
#
# mu_12:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.975           1.266            0.072          [ 10.443  15.227]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.883            12.246          13.197         13.892        14.821
#
#
# mu_21:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.019           1.198            0.059          [ 10.73   15.279]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.128           12.367          13.182         13.855        14.924
#
#
# mu_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.04            1.175            0.053          [ 10.801  15.361]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.288           12.416          13.197         13.885        14.943
#
#
# sigma:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	0.148            0.119            0.007            [ 0.037  0.361]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	0.045            0.079           0.112          0.175         0.436
#
#
# mu_11:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.805           1.676            0.133          [  9.311  15.321]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.133            11.756          13.063         14.089        15.256
#
#
# mu_6:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.221           1.206            0.056          [ 10.97   15.824]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.756           12.464          13.242         13.932        15.743
#
#
# mu_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.515           1.937            0.158          [ 10.038  17.232]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.207           12.18           13.286         14.834        17.819
#
#
# mu_13:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.648           2.38             0.208          [  9.373  18.03 ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.7              11.948          13.363         15.286        18.78
#
#
# mu_7:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.765           1.796            0.148          [  9.383  15.7  ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	8.782            11.61           13.021         14.162        15.404
#
#
# mu_2:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.827           3.022            0.278          [  8.24   18.951]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.026            11.48           13.544         15.9          20.523
#
#
# mu_20:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.135           1.136            0.041          [ 10.835  15.428]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.607           12.53           13.209         13.875        15.282
#
#
# beta_1:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	4.381            17.291           1.716          [-22.449  36.452]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-21.699          -11.817         6.365          16.641        41.42
#
#
# nu:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	1.012            0.042            0.004            [ 1.     1.057]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	1.0              1.0             1.0            1.001         1.119
#
#
# mu_9:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.604           2.322            0.209          [  8.552  16.44 ]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	7.62             10.997          12.764         14.517        16.059
#
#
# mu_18:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.917           1.382            0.092          [  9.954  15.028]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.643            12.127          13.199         13.935        14.888
#
#
# beta_0:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	8.723            17.38            1.725          [-22.984  36.295]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	-28.922          -3.332          7.536          24.808        34.977
#
#
# mu_24:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.623           2.295            0.199          [  9.48   17.858]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.799            11.983          13.361         15.206        18.591
#
#
# mu_4:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.869           1.5              0.109          [  9.784  15.152]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.416            11.97           13.176         13.998        15.026
#
#
# mu_14:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.455           2.851            0.266          [  7.454  17.194]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	6.385            10.484          12.51          14.913        16.704
#
#
# mu_16:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.748           1.848            0.154          [  9.352  15.867]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	8.607            11.546          12.971         14.2          15.468
#
#
# mu_5:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.616           2.282            0.204          [  8.619  16.381]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	7.71             11.05           12.806         14.484        16.001
#
#
# mu_17:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	13.277           1.298            0.072          [ 10.942  16.078]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	10.837           12.413          13.23          14.071        16.034
#
#
# udf:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	0.012            0.037            0.004            [ 0.     0.055]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	0.0              0.0             0.0            0.001         0.112
#
#
# mu_3:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.789           1.723            0.139          [  9.408  15.532]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.006            11.711          13.044         14.124        15.315
#
#
# mu_23:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.884           1.462            0.104          [  9.808  15.112]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.472            12.006          13.166         13.982        14.987
#
#
# mu_15:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.163           3.935            0.38           [  4.992  18.731]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	3.823            9.476           12.024         15.678        18.011
#
#
# mu_10:
#
# 	Mean             SD               MC Error        95% HPD interval
# 	------------------------------------------------------------------
# 	12.948           1.317            0.081          [ 10.173  15.069]
#
#
# 	Posterior quantiles:
#
# 	2.5             25              50              75             97.5
# 	 |---------------|===============|===============|---------------|
# 	9.808            12.188          13.205         13.91         14.84

# %%
plot_regression(cig.Wt, cig.Tar, M.mu, M.tau) # XXX CI's are not t-distributed
show()
posterior_hist(M.beta[0].trace(), "beta0")
legend()
show()
posterior_hist(M.beta[1].trace(), "beta1")
legend()
show()
posterior_hist(M.nu.trace(), "nu")
legend()
show()
# Out:
# CI: min=4.548629, max=13.738759
# CI: min=4.720511, max=14.232177

# %% [markdown]
# ## Repeated Measures

# %% [markdown]
# This final example uses the lung toxin clearance dataset from [H.A.Feldman](). Repeated measurements per subject are modeled via a hierarchic prior on the regression coefficients, and outliers are accommodated via a t-distribution for the likelihoods. There's a small bit of data cleaning to do on the [Feldman table]("feldman.csv"), to extract group1 data and exclude missing data
# . Let's wrangle this with a Pandas Dataframe.

# %%
feldman = pd.read_csv("feldman.csv", index_col=0)
group1 = feldman.ix[feldman.group == 1]
group1 = group1.ix[group1.retention.notnull()]
group1[:15]
